# %%
# %pip install miceforest
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.0/58.0 KB 1.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 9.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 KB 4.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 23.5 MB/s eta 0:00:00
# ...
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/pip/_vendor/pkg_resources/__init__.py", line 3021, in _dep_map
#     return self.__dep_map
#   File "/usr/local/lib/python3.9/dist-packages/pip/_vendor/pkg_resources/__init__.py", line 2815, in __getattr__
#     raise AttributeError(attr)
# AttributeError: _DistInfoDistribution__dep_map
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
# ...

# %%
from google.colab import drive

drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import csv
import pandas as pd
import numpy as np
from sklearn.linear_model import BayesianRidge

# %%
df_banxico = pd.read_csv('/content/drive/MyDrive/Ironhack/Proyecto4/r_1.csv')

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# %%
imp_m.fit_transform(df_banxico)[:][:-1]
# Out:
# array([[ 1.00000000e+00, -1.57897077e+06],
#        [ 2.00000000e+00, -1.56151678e+06],
#        [ 3.00000000e+00, -1.54406278e+06],
#        [ 4.00000000e+00, -1.52660879e+06],
#        [ 5.00000000e+00, -1.50915479e+06],
#        [ 6.00000000e+00, -1.49170080e+06],
#        [ 7.00000000e+00, -1.47424681e+06],
#        [ 8.00000000e+00, -1.45679281e+06],
#        [ 9.00000000e+00, -1.43933882e+06],
#        [ 1.00000000e+01, -1.42188483e+06],
#        [ 1.10000000e+01, -1.40443083e+06],
#        [ 1.20000000e+01, -1.38697684e+06],
#        [ 1.30000000e+01, -1.36952285e+06],
#        [ 1.40000000e+01, -1.35206885e+06],
#        [ 1.50000000e+01, -1.33461486e+06],
#        [ 1.60000000e+01, -1.31716087e+06],
#        [ 1.70000000e+01, -1.29970687e+06],
#        [ 1.80000000e+01, -1.28225288e+06],
#        [ 1.90000000e+01, -1.26479889e+06],
#        [ 2.00000000e+01, -1.24734489e+06],
#        [ 2.10000000e+01, -1.22989090e+06],
#        [ 2.20000000e+01, -1.21243690e+06],
# ...

# %%
df_banxico[['T','Q']] = imp_m.fit_transform(df_banxico)

# %%
df_banxico[['T','Q']].iloc[1]
# Out:
# T    2.000000e+00
# Q   -1.561517e+06
# Name: 1, dtype: float64

# %%
df_banxico.head()
# Out:
#       Fecha   IPC re_USD re_MXN V_P1 V_P2
# 0  01/01/90  3.85    NaN    NaN  NaN  NaN
# 1  01/02/90  1.84    NaN    NaN  NaN  NaN
# 2  01/03/90  1.53    NaN    NaN  NaN  NaN
# 3  01/04/90  1.96    NaN    NaN  NaN  NaN
# 4  01/05/90  2.31    NaN    NaN  NaN  NaN

# %%
df_banxico.dtypes
# Out:
# Fecha      object
# IPC       float64
# re_USD     object
# re_MXN     object
# V_P1       object
# V_P2       object
# dtype: object

# %%
imp_m = IterativeImputer(random_state = 13)

# %%
df_banxico_2 = pd.read_csv('/content/drive/MyDrive/Ironhack/Proyecto4/bd_banxico_2.csv')

# %%
df_banxico_3= pd.DataFrame(imp_m.fit_transform(df_banxico_2[['IPC', 're_USD', 're_MXN', 'V_P1', 'V_P2']]),
                           columns=['IPC', 're_USD', 're_MXN', 'V_P1', 'V_P2'])

# %%
df_banxico_3['Fecha']= df_banxico_2['Fecha'].copy()

# %%
df_banxico_3.reindex(columns=['Fecha', 'IPC', 're_USD', 're_MXN', 'V_P1', 'V_P2'])
# Out:
#         Fecha   IPC       re_USD        re_MXN      V_P1         V_P2
# 0    01/01/90  3.85  1839.328849   5586.655842  0.001679  1679.683490
# 1    01/02/90  1.84  1839.663669   5588.785289  0.001678  1678.326132
# 2    01/03/90  1.53  1839.715308   5589.113711  0.001678  1678.116788
# 3    01/04/90  1.96  1839.643680   5588.658158  0.001678  1678.407168
# 4    01/05/90  2.31  1839.585378   5588.287359  0.001679  1678.643524
# ..        ...   ...          ...           ...       ...          ...
# 391  01/08/22  0.80  5123.812800  13121.207000  0.001097  1097.161785
# 392  01/09/22  0.67  5036.821200  12753.919000  0.000964   963.745069
# 393  01/10/22  0.63  5361.385300  13909.816000  0.000881   880.761585
# 394  01/11/22  0.45  4817.584900  12234.404000  0.000884   884.457985
# 395  01/12/22  0.65  5353.001500  13679.624000  0.000563   563.477246
#
# [396 rows x 6 columns]

# %%
df_banxico.to_csv('/content/drive/MyDrive/Ironhack/Proyecto4/bd_banxico_meses.csv', index = False)
